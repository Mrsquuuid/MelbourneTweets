# %%
import pandas as pd
import numpy as np
import os

if __name__ == "__main__":
    folder = sys.argv[1]
    for root, dirs, files in os.walk(folder):
        for file in files:
            os.rename(os.path.join(root, file), os.path.join(folder, file))
    dir_list = [file for file in os.listdir(folder) if os.path.isdir(os.path.join(folder, file))]
    for each_dir in dir_list:
        os.rmdir(os.path.join(folder, each_dir))
    csv_list = [file for file in os.listdir(folder) if file.endswith("csv") ]
    df_list = [pd.read_csv(os.path.join(folder, file)) for file in csv_list]
    df = pd.concat(df_list)
    df.index = np.arange(len(df.index)) + 1
    df.to_csv(os.path.join(folder, "all.csv"), index=False)
    for file in csv_list:
        os.remove(os.path.join(folder, file))

# %%
dir_list
# Out:
# ['DESE_-_Labour_Market_-_Population_by_Age_Group__GCCSA__December_2020.csv (3)',
#  'DESE_-_Labour_Market_-_Population_by_Age_Group__GCCSA__December_2020.csv (4)',
#  'DESE_-_Labour_Market_-_Population_by_Age_Group__GCCSA__December_2020.csv (5)',
#  'DESE_-_Labour_Market_-_Population_by_Age_Group__GCCSA__December_2020.csv',
#  'DESE_-_Labour_Market_-_Population_by_Age_Group__GCCSA__December_2020.csv (2)',
#  'DESE_-_Labour_Market_-_Population_by_Age_Group__GCCSA__December_2020.csv (1)']

# %%
pd.read_csv("/Users/Ray/Desktop/test/all.csv")
# Out:
#     fid    gccsa_name_2016   state_code_2016    state_name_2016      age_grp  \
# 0     3     Greater Sydney                 1    New South Wales     35 to 44
# 1     9  Greater Melbourne                 2           Victoria     35 to 44
# 2    15   Greater Brisbane                 3         Queensland     35 to 44
# 3    21   Greater Adelaide                 4    South Australia     35 to 44
# 4    27      Greater Perth                 5  Western Australia     35 to 44
# 5     2     Greater Sydney                 1    New South Wales     25 to 34
# 6     8  Greater Melbourne                 2           Victoria     25 to 34
# 7    14   Greater Brisbane                 3         Queensland     25 to 34
# 8    20   Greater Adelaide                 4    South Australia     25 to 34
# 9    26      Greater Perth                 5  Western Australia     25 to 34
# 10    5     Greater Sydney                 1    New South Wales     55 to 64
# 11   11  Greater Melbourne                 2           Victoria     55 to 64
# 12   17   Greater Brisbane                 3         Queensland     55 to 64
# 13   23   Greater Adelaide                 4    South Australia     55 to 64
# 14   29      Greater Perth                 5  Western Australia     55 to 64
# 15    6     Greater Sydney                 1    New South Wales  65 and over
# 16   12  Greater Melbourne                 2           Victoria  65 and over
# 17   18   Greater Brisbane                 3         Queensland  65 and over
# 18   24   Greater Adelaide                 4    South Australia  65 and over
# 19   30      Greater Perth                 5  Western Australia  65 and over
# 20    1     Greater Sydney                 1    New South Wales     15 to 24
# 21    7  Greater Melbourne                 2           Victoria     15 to 24
# 22   13   Greater Brisbane                 3         Queensland     15 to 24
# 23   19   Greater Adelaide                 4    South Australia     15 to 24
# 24   25      Greater Perth                 5  Western Australia     15 to 24
# 25    4     Greater Sydney                 1    New South Wales     45 to 54
# 26   10  Greater Melbourne                 2           Victoria     45 to 54
# 27   16   Greater Brisbane                 3         Queensland     45 to 54
# 28   22   Greater Adelaide                 4    South Australia     45 to 54
# 29   28      Greater Perth                 5  Western Australia     45 to 54
#
#        pop  gccsa_code_2016   pop_distribution
# 0   780900            1GSYD               17.9
# 1   748100            2GMEL               17.7
# 2   355100            3GBRI               17.3
# 3   178300            4GADE               15.8
# 4   299100            5GPER               17.5
# 5   895500            1GSYD               20.5
# 6   890400            2GMEL               21.1
# 7   397300            3GBRI               19.3
# 8   192500            4GADE               17.0
# 9   319100            5GPER               18.6
# 10  574300            1GSYD               13.1
# 11  538000            2GMEL               12.7
# 12  273000            3GBRI               13.3
# 13  165500            4GADE               14.7
# 14  237000            5GPER               13.8
# 15  771300            1GSYD               17.6
# 16  733000            2GMEL               17.3
# 17  359100            3GBRI               17.5
# 18  246300            4GADE               21.8
# 19  319400            5GPER               18.7
# 20  689400            1GSYD               15.8
# 21  674500            2GMEL               16.0
# 22  342500            3GBRI               16.7
# 23  172700            4GADE               15.3
# 24  264700            5GPER               15.5
# 25  662800            1GSYD               15.2
# 26  641400            2GMEL               15.2
# 27  327200            3GBRI               15.9
# 28  173800            4GADE               15.4
# 29  272100            5GPER               15.9
